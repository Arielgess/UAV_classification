# %% [markdown]
# ### imports

# %%
# imports

import io
import glob
import os
import sys
from datetime import datetime
import pickle
import warnings
warnings.filterwarnings('ignore')
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import fft
import pandas as pd
import seaborn as sns
from scipy import interpolate
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr

# Machine Learning
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report


# prompt: Access a folder on google drive and import the data locally
from google.colab import drive
drive.mount('/content/drive/')
# helper files
sys.path.append('/content/drive/MyDrive/Final Project UAV/')
from UAV_project_preprocessing_and_visualization_helper_functions_full import *
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd /content/drive/MyDrive/Final Project UAV/
# Out:
# /content/drive/MyDrive/Final Project UAV

# %% [markdown]
# ### Loading results

# %%
all_results_df = pd.DataFrame()
for file in glob.glob('./Features Extraction Results/features_extraction_results*'):
  print(file)
  with open(file, 'rb') as f:
    all_results_df = all_results_df.append(pickle.load(f))

all_results_df.reset_index(drop=True, inplace=True)
# Out:
# ./Features Extraction Results/features_extraction_results_01_20_2024, 21:26:14
# ./Features Extraction Results/features_extraction_results_01_21_2024, 05:43:12
# ./Features Extraction Results/features_extraction_results_01_21_2024, 06:18:31

# %%
all_results_df = all_results_df[all_results_df['Model'] == 'RF']

# %%
len(all_results_df)
# Out:
# 540

# %%
all_results_df.head(3)
# Out:
#                datetime  Sample Duration  \
# 0  01/20/2024, 21:26:14                5
# 1  01/20/2024, 21:26:14                5
# 2  01/20/2024, 21:26:14                5
#
#                                           Test Files  \
# 0  [NIR_airplane_20230603-534_20230603-010658.jso...
# 1  [NIR_airplane_20230603-534_20230603-010658.jso...
# 2  [NIR_airplane_20230603-534_20230603-010658.jso...
#
#                                         Split Config  \
# 0  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 1  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 2  {'sample_duration': 5, 'overlap_factor': 0.25,...
#
#                                      Features Config Model  \
# 0  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 1  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 2  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                   Model Config  \
# 0   {'max_depth': 5, 'model_random_state': 24}
# 1   {'max_depth': 7, 'model_random_state': 24}
# 2  {'max_depth': 10, 'model_random_state': 24}
#
#                                    Evaluation Report  UAV precision  \
# 0  {'airplane': {'precision': 0.9127906976744186,...       0.696281
# 1  {'airplane': {'precision': 0.9464285714285714,...       0.739072
# 2  {'airplane': {'precision': 0.9634146341463414,...       0.766969
#
#    UAV recall    UAV f1  Total f1
# 0    0.820927  0.747642  0.871414
# 1    0.876978  0.796421  0.892718
# 2    0.886689  0.816136  0.899991

# %%
def extract_from_column(df, col, field):
  return df[col].apply(lambda x: x[field])

def features_type(df):
  # extremum = extract_from_column(df, 'Features Config', 'extremum')
  # curve = extract_from_column(df, 'Features Config', 'curve')
  # f = zip(extremum, curve)
  d_map = {
    (True, True): 'all',
    (True, False): 'range dependent',
    (False, True): 'range independent',
    (False, False): 'none'
  }
  return df['Features Config'].apply(lambda x: d_map[(x['extremum'], x['curve'])])

# %%
all_results_df['Max Depth'] = extract_from_column(all_results_df, 'Model Config', 'max_depth')
all_results_df['Max Depth'].fillna(value=100, inplace=True)
all_results_df['Model Random State'] = extract_from_column(all_results_df, 'Model Config', 'model_random_state')
all_results_df['Split Random State'] = extract_from_column(all_results_df, 'Split Config', 'random_state')
all_results_df['Features Type'] = features_type(all_results_df)

# %%
all_results_df.head(3)
# Out:
#                datetime  Sample Duration  \
# 0  01/20/2024, 21:26:14                5
# 1  01/20/2024, 21:26:14                5
# 2  01/20/2024, 21:26:14                5
#
#                                           Test Files  \
# 0  [NIR_airplane_20230603-534_20230603-010658.jso...
# 1  [NIR_airplane_20230603-534_20230603-010658.jso...
# 2  [NIR_airplane_20230603-534_20230603-010658.jso...
#
#                                         Split Config  \
# 0  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 1  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 2  {'sample_duration': 5, 'overlap_factor': 0.25,...
#
#                                      Features Config Model  \
# 0  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 1  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 2  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                   Model Config  \
# 0   {'max_depth': 5, 'model_random_state': 24}
# 1   {'max_depth': 7, 'model_random_state': 24}
# 2  {'max_depth': 10, 'model_random_state': 24}
#
#                                    Evaluation Report  UAV precision  \
# 0  {'airplane': {'precision': 0.9127906976744186,...       0.696281
# 1  {'airplane': {'precision': 0.9464285714285714,...       0.739072
# 2  {'airplane': {'precision': 0.9634146341463414,...       0.766969
#
#    UAV recall    UAV f1  Total f1  Max Depth  Model Random State  \
# 0    0.820927  0.747642  0.871414        5.0                  24
# 1    0.876978  0.796421  0.892718        7.0                  24
# 2    0.886689  0.816136  0.899991       10.0                  24
#
#    Split Random State Features Type
# 0                  24           all
# 1                  24           all
# 2                  24           all

# %%
all_results_df[all_results_df['UAV f1'] == all_results_df['UAV f1'].max()]
# Out:
#                 datetime  Sample Duration  \
# 18  01/20/2024, 21:26:14               25
#
#                                            Test Files  \
# 18  [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                          Split Config  \
# 18  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                       Features Config Model  \
# 18  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                    Model Config  \
# 18  {'max_depth': 10, 'model_random_state': 24}
#
#                                     Evaluation Report  UAV precision  \
# 18  {'airplane': {'precision': 0.9393939393939394,...       0.894219
#
#     UAV recall    UAV f1  Total f1  Max Depth  Model Random State  \
# 18    0.927373  0.909235  0.949868       10.0                  24
#
#     Split Random State Features Type
# 18                  24           all

# %%
all_results_df['Evaluation Report'].iloc[18]
# Out:
# {'airplane': {'precision': 0.9393939393939394,
#   'recall': 0.9393939393939394,
#   'f1-score': 0.9393939393939394,
#   'support': 33},
#  'uav': {'precision': 0.7741935483870968,
#   'recall': 0.9411764705882353,
#   'f1-score': 0.8495575221238938,
#   'support': 51},
#  'bird': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#  'static-object': {'precision': 0.9743589743589743,
#   'recall': 0.912,
#   'f1-score': 0.9421487603305785,
#   'support': 125},
#  'accuracy': 0.910377358490566,
#  'macro avg': {'precision': 0.6719866155350026,
#   'recall': 0.6981426024955437,
#   'f1-score': 0.6827750554621029,
#   'support': 212},
#  'weighted avg': {'precision': 0.9069752017104421,
#   'recall': 0.910377358490566,
#   'f1-score': 0.9061133427813248,
#   'support': 212}}

# %% [markdown]
# ### Slicing

# %%
slice_config = {
    'Model' : 'RF',
    'Split Random State' : 42,
    'Features Type' : 'all'
}

# %%
# prompt: slice a dataframe according to a given column value dictionary

slice_df = all_results_df[all_results_df['Model'] == slice_config['Model']]
slice_df = slice_df[slice_df['Features Type'] == slice_config['Features Type']]
# slice_df = slice_df[slice_df['Split Random State'] == slice_config['Split Random State']]

# %%
slice_df.tail(5)
# Out:
#                  datetime  Sample Duration  \
# 175  01/20/2024, 21:26:14               20
# 176  01/20/2024, 21:26:14               25
# 177  01/20/2024, 21:26:14               25
# 178  01/20/2024, 21:26:14               25
# 179  01/20/2024, 21:26:14               25
#
#                                             Test Files  \
# 175  [NIR_airplane_20231023-15264_20231023-183229.j...
# 176  [NIR_airplane_20231024-7069_20231024-021810.js...
# 177  [NIR_airplane_20231024-7069_20231024-021810.js...
# 178  [NIR_airplane_20231024-7069_20231024-021810.js...
# 179  [NIR_airplane_20231024-7069_20231024-021810.js...
#
#                                           Split Config  \
# 175  {'sample_duration': 20, 'overlap_factor': 0.25...
# 176  {'sample_duration': 25, 'overlap_factor': 0.25...
# 177  {'sample_duration': 25, 'overlap_factor': 0.25...
# 178  {'sample_duration': 25, 'overlap_factor': 0.25...
# 179  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 175  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 176  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 177  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 178  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 179  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                       Model Config  \
# 175  {'max_depth': None, 'model_random_state': 42}
# 176     {'max_depth': 5, 'model_random_state': 42}
# 177     {'max_depth': 7, 'model_random_state': 42}
# 178    {'max_depth': 10, 'model_random_state': 42}
# 179  {'max_depth': None, 'model_random_state': 42}
#
#                                      Evaluation Report  UAV precision  \
# 175  {'airplane': {'precision': 0.9655172413793104,...       0.874921
# 176  {'airplane': {'precision': 0.8709677419354839,...       0.835018
# 177  {'airplane': {'precision': 0.9642857142857143,...       0.841731
# 178  {'airplane': {'precision': 0.9642857142857143,...       0.848988
# 179  {'airplane': {'precision': 0.9642857142857143,...       0.848599
#
#      UAV recall    UAV f1  Total f1  Max Depth  Model Random State  \
# 175    0.894464  0.882631  0.923814      100.0                  42
# 176    0.871863  0.843402  0.909777        5.0                  42
# 177    0.908042  0.862163  0.919370        7.0                  42
# 178    0.908042  0.866033  0.921693       10.0                  42
# 179    0.913170  0.868848  0.922322      100.0                  42
#
#      Split Random State Features Type
# 175                  42           all
# 176                  42           all
# 177                  42           all
# 178                  42           all
# 179                  42           all

# %%
slice_df['UAV recall'].max()
# Out:
# 0.9333725490196079

# %%
slice_df[slice_df['UAV recall'] == slice_df['UAV recall'].max()]
# Out:
#                  datetime  Sample Duration  \
# 138  01/20/2024, 21:26:14               25
# 139  01/20/2024, 21:26:14               25
#
#                                             Test Files  \
# 138  [NIR_airplane_20231023-13275_20231023-181630.j...
# 139  [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                           Split Config  \
# 138  {'sample_duration': 25, 'overlap_factor': 0.25...
# 139  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 138  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 139  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                       Model Config  \
# 138    {'max_depth': 10, 'model_random_state': 42}
# 139  {'max_depth': None, 'model_random_state': 42}
#
#                                      Evaluation Report  UAV precision  \
# 138  {'airplane': {'precision': 0.96875, 'recall': ...       0.886859
# 139  {'airplane': {'precision': 0.96875, 'recall': ...       0.886859
#
#      UAV recall    UAV f1  Total f1  Max Depth  Model Random State  \
# 138    0.933373  0.907559  0.949113       10.0                  42
# 139    0.933373  0.907559  0.949113      100.0                  42
#
#      Split Random State Features Type
# 138                  24           all
# 139                  24           all

# %%
slice_df[slice_df['UAV precision'] == slice_df['UAV precision'].max()]
# Out:
#                 datetime  Sample Duration  \
# 18  01/20/2024, 21:26:14               25
#
#                                            Test Files  \
# 18  [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                          Split Config  \
# 18  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                       Features Config Model  \
# 18  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                    Model Config  \
# 18  {'max_depth': 10, 'model_random_state': 24}
#
#                                     Evaluation Report  UAV precision  \
# 18  {'airplane': {'precision': 0.9393939393939394,...       0.894219
#
#     UAV recall    UAV f1  Total f1  Max Depth  Model Random State  \
# 18    0.927373  0.909235  0.949868       10.0                  24
#
#     Split Random State Features Type
# 18                  24           all

# %%
slice_df[slice_df['UAV f1'] == slice_df['UAV f1'].max()]
# Out:
#                 datetime  Sample Duration  \
# 18  01/20/2024, 21:26:14               25
#
#                                            Test Files  \
# 18  [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                          Split Config  \
# 18  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                       Features Config Model  \
# 18  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                    Model Config  \
# 18  {'max_depth': 10, 'model_random_state': 24}
#
#                                     Evaluation Report  UAV precision  \
# 18  {'airplane': {'precision': 0.9393939393939394,...       0.894219
#
#     UAV recall    UAV f1  Total f1  Max Depth  Model Random State  \
# 18    0.927373  0.909235  0.949868       10.0                  24
#
#     Split Random State Features Type
# 18                  24           all

# %%
g = sns.catplot(data=slice_df, x = "Sample Duration", y = "UAV f1", hue = "Max Depth", col="Split Random State", kind="bar", aspect=1.2, palette ="bright")

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
slice_df = slice_df[slice_df['Split Random State'] == slice_config['Split Random State']]

# %%
g = sns.catplot(data=slice_df, x = "Sample Duration", y = "UAV f1", hue = "Max Depth", col="Split Random State", kind="bar", aspect = 2, palette ="bright")

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
# g = sns.catplot(data=slice_df, x = "Max Depth", y = "UAV recall", hue = "Sample Duration", col="Split Random State", kind="bar", aspect = 2)

# for ax in g.axes.ravel():
#     for c in ax.containers:
#         labels = ['%0.2f' % v for v in c.datavalues]
#         ax.bar_label(c, labels=labels, label_type='edge')
#     # plt.xticks(rotation=45)
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
#     ax.margins(y=0.2)

# %% [markdown]
# ### Compare features

# %%
feat_slice_df = all_results_df[all_results_df['Model'] == slice_config['Model']]
feat_slice_df = feat_slice_df[feat_slice_df['Max Depth'] == 10]
feat_slice_df = feat_slice_df[feat_slice_df['Split Random State'] == slice_config['Split Random State']]

# %%
hue_order = ['range dependent','range independent', 'all']

g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="bar",hue_order=hue_order, aspect = 2)

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
# hue_order = ['range dependent','range independent', 'all']

# g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="bar",hue_order=hue_order, aspect = 2)
g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="point", aspect = 2)

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)
