# %% [markdown]
# ### imports

# %%
# imports

import io
import glob
import os
import sys
from datetime import datetime
import pickle
import warnings
warnings.filterwarnings('ignore')
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import fft
import pandas as pd
import seaborn as sns
from scipy import interpolate
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr

# Machine Learning
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report


# prompt: Access a folder on google drive and import the data locally
from google.colab import drive
drive.mount('/content/drive/')
# helper files
sys.path.append('/content/drive/MyDrive/Final Project UAV/')
from UAV_project_preprocessing_and_visualization_helper_functions import *
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Final Project UAV/
# Out:
# /content/drive/MyDrive/Final Project UAV

# %% [markdown]
# ### Loading results

# %%
all_results_df = pd.DataFrame()
for file in glob.glob('./Features Extraction Results/features_extraction_results*'):
  print(file)
  with open(file, 'rb') as f:
    all_results_df = all_results_df.append(pickle.load(f))

all_results_df.reset_index(drop=True, inplace=True)
# Out:
# ./Features Extraction Results/features_extraction_results_01_20_2024, 21:26:14
# ./Features Extraction Results/features_extraction_results_01_21_2024, 05:43:12
# ./Features Extraction Results/features_extraction_results_01_21_2024, 06:18:31
# ./Features Extraction Results/features_extraction_results_01_22_2024, 06:47:07
# ./Features Extraction Results/features_extraction_results_01_22_2024, 07:28:08
# ./Features Extraction Results/features_extraction_results_01_22_2024, 07:41:17
# ./Features Extraction Results/features_extraction_results_01_22_2024, 09:20:06
# ./Features Extraction Results/features_extraction_results_01_22_2024, 13:18:35
# ./Features Extraction Results/features_extraction_results_01_22_2024, 13:24:23
# ./Features Extraction Results/features_extraction_results_01_22_2024, 21:19:19
# ./Features Extraction Results/features_extraction_results_01_22_2024, 21:36:27

# %%
all_results_df = all_results_df[all_results_df['Model'] == 'XGB']
all_results_df.reset_index(drop=True, inplace=True)

# %%
len(all_results_df)
# Out:
# 160

# %%
all_results_df.sample(6)
# Out:
#                  datetime  Sample Duration  \
# 133  01/22/2024, 21:36:27               20
# 112  01/22/2024, 21:36:27               15
# 143  01/22/2024, 21:36:27               20
# 95   01/22/2024, 21:36:27                5
# 38   01/22/2024, 21:19:19               15
# 23   01/22/2024, 21:19:19               10
#
#                                             Test Files  \
# 133  [NIR_airplane_20231023-15264_20231023-183229.j...
# 112  [NIR_airplane_20231023-15264_20231023-183229.j...
# 143  [NIR_airplane_20231023-15264_20231023-183229.j...
# 95   [NIR_airplane_20231023-13275_20231023-181630.j...
# 38   [NIR_airplane_20231023-15264_20231023-183229.j...
# 23   [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                           Split Config  \
# 133  {'sample_duration': 20, 'overlap_factor': 0.25...
# 112  {'sample_duration': 15, 'overlap_factor': 0.25...
# 143  {'sample_duration': 20, 'overlap_factor': 0.25...
# 95   {'sample_duration': 5, 'overlap_factor': 0.25,...
# 38   {'sample_duration': 15, 'overlap_factor': 0.25...
# 23   {'sample_duration': 10, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 133  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 112  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 143  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 95   {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 38   {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
# 23   {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
#
#                                           Model Config  \
# 133  {'max_depth': 4, 'model_random_state': 42, 'et...
# 112  {'max_depth': 2, 'model_random_state': 42, 'et...
# 143  {'max_depth': 10, 'model_random_state': 42, 'e...
# 95   {'max_depth': 10, 'model_random_state': 42, 'e...
# 38   {'max_depth': 4, 'model_random_state': 42, 'et...
# 23   {'max_depth': 4, 'model_random_state': 42, 'et...
#
#                                      Evaluation Report  UAV precision  \
# 133  {'airplane': {'precision': 0.9333333333333333,...       0.855373
# 112  {'airplane': {'precision': 0.8695652173913043,...       0.864556
# 143  {'airplane': {'precision': 0.875, 'recall': 1....       0.895942
# 95   {'airplane': {'precision': 0.6792452830188679,...       0.465630
# 38   {'airplane': {'precision': 0.8695652173913043,...       0.825476
# 23   {'airplane': {'precision': 0.22926829268292684...       0.515846
#
#      UAV recall    UAV f1  Total f1
# 133    0.902969  0.876075  0.923833
# 112    0.860943  0.859100  0.924769
# 143    0.890111  0.892186  0.918851
# 95     0.548498  0.420374  0.722771
# 38     0.897229  0.850896  0.913760
# 23     0.731278  0.564700  0.722245

# %%
def extract_from_column(df, col, field):
  return df[col].apply(lambda x: x[field])

def features_type(df):
  # extremum = extract_from_column(df, 'Features Config', 'extremum')
  # curve = extract_from_column(df, 'Features Config', 'curve')
  # f = zip(extremum, curve)
  d_map = {
    (True, True): 'all',
    (True, False): 'range dependent',
    (False, True): 'range independent',
    (False, False): 'none'
  }
  return df['Features Config'].apply(lambda x: d_map[(x['extremum'], x['curve'])])

# %%
all_results_df['Max Depth'] = extract_from_column(all_results_df, 'Model Config', 'max_depth')
all_results_df['Max Depth'].fillna(value=100, inplace=True)
all_results_df['Model Random State'] = extract_from_column(all_results_df, 'Model Config', 'model_random_state')
all_results_df['eta'] = extract_from_column(all_results_df, 'Model Config', 'eta')
all_results_df['Split Random State'] = extract_from_column(all_results_df, 'Split Config', 'random_state')
all_results_df['Features Type'] = features_type(all_results_df)

# %%
all_results_df.sample(10)
# Out:
#                  datetime  Sample Duration  \
# 58   01/22/2024, 21:19:19               20
# 151  01/22/2024, 21:36:27               25
# 112  01/22/2024, 21:36:27               15
# 86   01/22/2024, 21:36:27                5
# 35   01/22/2024, 21:19:19               15
# 124  01/22/2024, 21:36:27               15
# 96   01/22/2024, 21:36:27               10
# 21   01/22/2024, 21:19:19               10
# 99   01/22/2024, 21:36:27               10
# 63   01/22/2024, 21:19:19               20
#
#                                             Test Files  \
# 58   [NIR_airplane_20231023-15264_20231023-183229.j...
# 151  [NIR_airplane_20231024-7069_20231024-021810.js...
# 112  [NIR_airplane_20231023-15264_20231023-183229.j...
# 86   [NIR_airplane_20231023-13275_20231023-181630.j...
# 35   [NIR_airplane_20231023-15264_20231023-183229.j...
# 124  [NIR_airplane_20231023-15264_20231023-183229.j...
# 96   [NIR_airplane_20231023-13275_20231023-181630.j...
# 21   [NIR_airplane_20231023-13275_20231023-181630.j...
# 99   [NIR_airplane_20231023-13275_20231023-181630.j...
# 63   [NIR_airplane_20231023-15264_20231023-183229.j...
#
#                                           Split Config  \
# 58   {'sample_duration': 20, 'overlap_factor': 0.25...
# 151  {'sample_duration': 25, 'overlap_factor': 0.25...
# 112  {'sample_duration': 15, 'overlap_factor': 0.25...
# 86   {'sample_duration': 5, 'overlap_factor': 0.25,...
# 35   {'sample_duration': 15, 'overlap_factor': 0.25...
# 124  {'sample_duration': 15, 'overlap_factor': 0.25...
# 96   {'sample_duration': 10, 'overlap_factor': 0.25...
# 21   {'sample_duration': 10, 'overlap_factor': 0.25...
# 99   {'sample_duration': 10, 'overlap_factor': 0.25...
# 63   {'sample_duration': 20, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 58   {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
# 151  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 112  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 86   {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 35   {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
# 124  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 96   {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 21   {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
# 99   {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 63   {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
#
#                                           Model Config  \
# 58   {'max_depth': 7, 'model_random_state': 42, 'et...
# 151  {'max_depth': 4, 'model_random_state': 42, 'et...
# 112  {'max_depth': 2, 'model_random_state': 42, 'et...
# 86   {'max_depth': 4, 'model_random_state': 42, 'et...
# 35   {'max_depth': 2, 'model_random_state': 42, 'et...
# 124  {'max_depth': 10, 'model_random_state': 42, 'e...
# 96   {'max_depth': 2, 'model_random_state': 42, 'et...
# 21   {'max_depth': 4, 'model_random_state': 42, 'et...
# 99   {'max_depth': 2, 'model_random_state': 42, 'et...
# 63   {'max_depth': 10, 'model_random_state': 42, 'e...
#
#                                      Evaluation Report  UAV precision  \
# 58   {'airplane': {'precision': 0.9032258064516129,...       0.883400
# 151  {'airplane': {'precision': 0.9032258064516129,...       0.625861
# 112  {'airplane': {'precision': 0.8695652173913043,...       0.864556
# 86   {'airplane': {'precision': 0.9234972677595629,...       0.815725
# 35   {'airplane': {'precision': 0.7, 'recall': 0.83...       0.452880
# 124  {'airplane': {'precision': 0.8888888888888888,...       0.873916
# 96   {'airplane': {'precision': 0.95, 'recall': 0.9...       0.809039
# 21   {'airplane': {'precision': 0.9285714285714286,...       0.833079
# 99   {'airplane': {'precision': 0.46706586826347307...       0.571304
# 63   {'airplane': {'precision': 0.875, 'recall': 1....       0.802763
#
#      UAV recall    UAV f1  Total f1  Max Depth  Model Random State   eta  \
# 58     0.943595  0.909847  0.919554          7                  42  1.00
# 151    0.704706  0.641155  0.699868          4                  42  3.00
# 112    0.860943  0.859100  0.924769          2                  42  0.05
# 86     0.899687  0.849625  0.925587          4                  42  1.00
# 35     0.674223  0.530946  0.693920          2                  42  3.00
# 124    0.917556  0.892252  0.938274         10                  42  0.05
# 96     0.799436  0.800542  0.903825          2                  42  0.05
# 21     0.883938  0.852516  0.918637          4                  42  0.10
# 99     0.686069  0.609070  0.754050          2                  42  3.00
# 63     0.813319  0.806469  0.855917         10                  42  3.00
#
#      Split Random State      Features Type
# 58                   42  range independent
# 151                  42                all
# 112                  42                all
# 86                   42                all
# 35                   42  range independent
# 124                  42                all
# 96                   42                all
# 21                   42  range independent
# 99                   42                all
# 63                   42  range independent

# %%
all_results_df[all_results_df['UAV f1'] == all_results_df['UAV f1'].max()]
# Out:
#                 datetime  Sample Duration  \
# 62  01/22/2024, 21:19:19               20
#
#                                            Test Files  \
# 62  [NIR_airplane_20231023-15264_20231023-183229.j...
#
#                                          Split Config  \
# 62  {'sample_duration': 20, 'overlap_factor': 0.25...
#
#                                       Features Config Model  \
# 62  {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
#
#                                          Model Config  \
# 62  {'max_depth': 10, 'model_random_state': 42, 'e...
#
#                                     Evaluation Report  UAV precision  \
# 62  {'airplane': {'precision': 0.9333333333333333,...       0.903826
#
#     UAV recall    UAV f1  Total f1  Max Depth  Model Random State  eta  \
# 62    0.932493  0.917546  0.927369         10                  42  1.0
#
#     Split Random State      Features Type
# 62                  42  range independent

# %%
all_results_df['Evaluation Report'].iloc[62]
# Out:
# {'airplane': {'precision': 0.9333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.9655172413793104,
#   'support': 28},
#  'uav': {'precision': 0.7058823529411765,
#   'recall': 0.9230769230769231,
#   'f1-score': 0.8000000000000002,
#   'support': 39},
#  'bird': {'precision': 1.0,
#   'recall': 0.14285714285714285,
#   'f1-score': 0.25,
#   'support': 7},
#  'static-object': {'precision': 0.9850746268656716,
#   'recall': 0.9295774647887324,
#   'f1-score': 0.9565217391304348,
#   'support': 142},
#  'accuracy': 0.9120370370370371,
#  'macro avg': {'precision': 0.9060725782850454,
#   'recall': 0.7488778826806997,
#   'f1-score': 0.7430097451274362,
#   'support': 216},
#  'weighted avg': {'precision': 0.9284413986711323,
#   'recall': 0.9120370370370371,
#   'f1-score': 0.9065304153478816,
#   'support': 216}}

# %% [markdown]
# ### Slicing

# %%
slice_config = {
    'Model' : 'XGB',
    'Split Random State' : 42,
    'Features Type' : 'all',
    'eta' : 0.1
}

# %%
# prompt: slice a dataframe according to a given column value dictionary

# slice_df = all_results_df[all_results_df['Model'] == slice_config['Model']]
slice_df = all_results_df[all_results_df['Features Type'] == slice_config['Features Type']]
slice_df = slice_df[slice_df['eta'] == slice_config['eta']]

# %%
# slice_df['UAV recall'].max()

# %%
# slice_df[slice_df['UAV recall'] == slice_df['UAV recall'].max()]

# %%
# slice_df[slice_df['UAV precision'] == slice_df['UAV precision'].max()]

# %%
# slice_df[slice_df['UAV f1'] == slice_df['UAV f1'].max()]

# %%
g = sns.catplot(data=slice_df, x = "Sample Duration", y = "UAV f1", hue = "Max Depth", col="Split Random State", kind="bar", aspect = 2, palette ="bright")

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
# g = sns.catplot(data=slice_df, x = "Max Depth", y = "UAV recall", hue = "Sample Duration", col="Split Random State", kind="bar", aspect = 2)

# for ax in g.axes.ravel():
#     for c in ax.containers:
#         labels = ['%0.2f' % v for v in c.datavalues]
#         ax.bar_label(c, labels=labels, label_type='edge')
#     # plt.xticks(rotation=45)
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
#     ax.margins(y=0.2)

# %% [markdown]
# ### Compare features

# %%
feat_slice_df = all_results_df[all_results_df['Model'] == slice_config['Model']]
feat_slice_df = feat_slice_df[feat_slice_df['Max Depth'] == 4]
feat_slice_df = feat_slice_df[feat_slice_df['eta'] == slice_config['eta']]

# %%
hue_order = ['range independent', 'all']

g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="bar",hue_order=hue_order, aspect = 2)

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
# hue_order = ['range dependent','range independent', 'all']

# g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="bar",hue_order=hue_order, aspect = 2)
g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="point", aspect = 2)

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)
