# %% [markdown]
# ### imports

# %%
# imports

import io
import glob
import os
import sys
from datetime import datetime
import pickle
import warnings
warnings.filterwarnings('ignore')
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import fft
import pandas as pd
import seaborn as sns
from scipy import interpolate
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr

# Machine Learning
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report


# prompt: Access a folder on google drive and import the data locally
from google.colab import drive
drive.mount('/content/drive/')
# helper files
sys.path.append('/content/drive/MyDrive/Final Project UAV/')
from UAV_project_preprocessing_and_visualization_helper_functions_full import *
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Final Project UAV/
# Out:
# /content/drive/MyDrive/Final Project UAV

# %% [markdown]
# ### Loading results

# %%
all_results_df = pd.DataFrame()
for file in glob.glob('./Features Extraction Results/features_extraction_results*'):
  print(file)
  with open(file, 'rb') as f:
    all_results_df = all_results_df.append(pickle.load(f))

all_results_df.reset_index(drop=True, inplace=True)
# Out:
# ./Features Extraction Results/features_extraction_results_01_20_2024, 21:26:14
# ./Features Extraction Results/features_extraction_results_01_21_2024, 05:43:12
# ./Features Extraction Results/features_extraction_results_01_21_2024, 06:18:31
# ./Features Extraction Results/features_extraction_results_01_22_2024, 06:47:07
# ./Features Extraction Results/features_extraction_results_01_22_2024, 07:28:08
# ./Features Extraction Results/features_extraction_results_01_22_2024, 07:41:17
# ./Features Extraction Results/features_extraction_results_01_22_2024, 09:20:06
# ./Features Extraction Results/features_extraction_results_01_22_2024, 13:18:35
# ./Features Extraction Results/features_extraction_results_01_22_2024, 13:24:23
# ./Features Extraction Results/features_extraction_results_01_22_2024, 21:19:19
# ./Features Extraction Results/features_extraction_results_01_22_2024, 21:36:27
# ./Features Extraction Results/features_extraction_results_01_24_2024, 07:58:06
# ./Features Extraction Results/features_extraction_results_01_24_2024, 08:59:36
# ./Features Extraction Results/features_extraction_results_01_24_2024, 14:49:47
# ./Features Extraction Results/features_extraction_results_01_24_2024, 15:14:30
# ./Features Extraction Results/features_extraction_results_01_24_2024, 15:44:48
# ./Features Extraction Results/features_extraction_results_01_24_2024, 20:09:26
# ./Features Extraction Results/features_extraction_results_01_25_2024, 06:08:31

# %%
results_RF = all_results_df[all_results_df['Model'] == 'RF']
results_XGB = all_results_df[all_results_df['Model'] == 'XGB']

# %%
def extract_from_column(df, col, field):
  return df[col].apply(lambda x: x[field])

def features_type(df):
  # extremum = extract_from_column(df, 'Features Config', 'extremum')
  # curve = extract_from_column(df, 'Features Config', 'curve')
  # f = zip(extremum, curve)
  d_map = {
    (True, True): 'all',
    (True, False): 'range dependent',
    (False, True): 'range independent',
    (False, False): 'none'
  }
  return df['Features Config'].apply(lambda x: d_map[(x['extremum'], x['curve'])])

# %% [markdown]
# ####RF

# %%
results_RF
# Out:
#                  datetime  Sample Duration  \
# 0    01/20/2024, 21:26:14                5
# 1    01/20/2024, 21:26:14                5
# 2    01/20/2024, 21:26:14                5
# 3    01/20/2024, 21:26:14                5
# 4    01/20/2024, 21:26:14               10
# ..                    ...              ...
# 535  01/21/2024, 06:18:31               20
# 536  01/21/2024, 06:18:31               25
# 537  01/21/2024, 06:18:31               25
# 538  01/21/2024, 06:18:31               25
# 539  01/21/2024, 06:18:31               25
#
#                                             Test Files  \
# 0    [NIR_airplane_20230603-534_20230603-010658.jso...
# 1    [NIR_airplane_20230603-534_20230603-010658.jso...
# 2    [NIR_airplane_20230603-534_20230603-010658.jso...
# 3    [NIR_airplane_20230603-534_20230603-010658.jso...
# 4    [NIR_airplane_20230603-534_20230603-010658.jso...
# ..                                                 ...
# 535  [NIR_airplane_20231023-15264_20231023-183229.j...
# 536  [NIR_airplane_20231024-7069_20231024-021810.js...
# 537  [NIR_airplane_20231024-7069_20231024-021810.js...
# 538  [NIR_airplane_20231024-7069_20231024-021810.js...
# 539  [NIR_airplane_20231024-7069_20231024-021810.js...
#
#                                           Split Config  \
# 0    {'sample_duration': 5, 'overlap_factor': 0.25,...
# 1    {'sample_duration': 5, 'overlap_factor': 0.25,...
# 2    {'sample_duration': 5, 'overlap_factor': 0.25,...
# 3    {'sample_duration': 5, 'overlap_factor': 0.25,...
# 4    {'sample_duration': 10, 'overlap_factor': 0.25...
# ..                                                 ...
# 535  {'sample_duration': 20, 'overlap_factor': 0.25...
# 536  {'sample_duration': 25, 'overlap_factor': 0.25...
# 537  {'sample_duration': 25, 'overlap_factor': 0.25...
# 538  {'sample_duration': 25, 'overlap_factor': 0.25...
# 539  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 0    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 1    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 2    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 3    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 4    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# ..                                                 ...   ...
# 535  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 536  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 537  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 538  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 539  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                       Model Config  \
# 0       {'max_depth': 5, 'model_random_state': 24}
# 1       {'max_depth': 7, 'model_random_state': 24}
# 2      {'max_depth': 10, 'model_random_state': 24}
# 3    {'max_depth': None, 'model_random_state': 24}
# 4       {'max_depth': 5, 'model_random_state': 24}
# ..                                             ...
# 535  {'max_depth': None, 'model_random_state': 42}
# 536     {'max_depth': 5, 'model_random_state': 42}
# 537     {'max_depth': 7, 'model_random_state': 42}
# 538    {'max_depth': 10, 'model_random_state': 42}
# 539  {'max_depth': None, 'model_random_state': 42}
#
#                                      Evaluation Report  UAV precision  \
# 0    {'airplane': {'precision': 0.9127906976744186,...       0.696281
# 1    {'airplane': {'precision': 0.9464285714285714,...       0.739072
# 2    {'airplane': {'precision': 0.9634146341463414,...       0.766969
# 3    {'airplane': {'precision': 0.975609756097561, ...       0.774619
# 4    {'airplane': {'precision': 0.9305555555555556,...       0.728097
# ..                                                 ...            ...
# 535  {'airplane': {'precision': 0.84375, 'recall': ...       0.844035
# 536  {'airplane': {'precision': 0.7878787878787878,...       0.791844
# 537  {'airplane': {'precision': 0.7878787878787878,...       0.802885
# 538  {'airplane': {'precision': 0.8, 'recall': 0.84...       0.797189
# 539  {'airplane': {'precision': 0.7941176470588235,...       0.802775
#
#      UAV recall    UAV f1  Total f1 Training Config
# 0      0.820927  0.747642  0.871414             NaN
# 1      0.876978  0.796421  0.892718             NaN
# 2      0.886689  0.816136  0.899991             NaN
# 3      0.874580  0.815020  0.901053             NaN
# 4      0.793929  0.748937  0.881886             NaN
# ..          ...       ...       ...             ...
# 535    0.866021  0.852412  0.881536             NaN
# 536    0.810647  0.793590  0.892893             NaN
# 537    0.847730  0.819182  0.896244             NaN
# 538    0.849378  0.819052  0.894696             NaN
# 539    0.880321  0.835095  0.899086             NaN
#
# [540 rows x 13 columns]

# %%
max_idx_RF = results_RF.groupby(['Sample Duration','Model'])['UAV f1'].idxmax()
df_max_RF = results_RF.loc[max_idx_RF.values]

# %%
#Extracting test reports
df_max_RF['test UAV report'] = extract_from_column(df_max_RF, 'Evaluation Report', 'uav')
df_max_RF['test UAV precision'] = extract_from_column(df_max_RF, 'test UAV report', 'precision')
df_max_RF['test UAV recall'] = extract_from_column(df_max_RF, 'test UAV report', 'recall')
df_max_RF['test UAV f1-score'] = extract_from_column(df_max_RF, 'test UAV report', 'f1-score')

# %%
df_max_RF
# Out:
#                  datetime  Sample Duration  \
# 123  01/20/2024, 21:26:14                5
# 47   01/20/2024, 21:26:14               10
# 171  01/20/2024, 21:26:14               15
# 234  01/21/2024, 05:43:12               20
# 18   01/20/2024, 21:26:14               25
#
#                                             Test Files  \
# 123  [NIR_airplane_20230603-534_20230603-010658.jso...
# 47   [NIR_airplane_20231023-13275_20231023-181630.j...
# 171  [NIR_airplane_20231023-15264_20231023-183229.j...
# 234  [NIR_airplane_20231023-15264_20231023-183229.j...
# 18   [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                           Split Config  \
# 123  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 47   {'sample_duration': 10, 'overlap_factor': 0.25...
# 171  {'sample_duration': 15, 'overlap_factor': 0.25...
# 234  {'sample_duration': 20, 'overlap_factor': 0.25...
# 18   {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 123  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 47   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 171  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 234  {'date': 2012024, 'extremum': False, 'std': Fa...    RF
# 18   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                       Model Config  \
# 123  {'max_depth': None, 'model_random_state': 42}
# 47   {'max_depth': None, 'model_random_state': 24}
# 171  {'max_depth': None, 'model_random_state': 42}
# 234    {'max_depth': 10, 'model_random_state': 24}
# 18     {'max_depth': 10, 'model_random_state': 24}
#
#                                      Evaluation Report  UAV precision  \
# 123  {'airplane': {'precision': 0.9810126582278481,...       0.778403
# 47   {'airplane': {'precision': 0.9629629629629629,...       0.827140
# 171  {'airplane': {'precision': 0.8636363636363636,...       0.860131
# 234  {'airplane': {'precision': 0.9642857142857143,...       0.870085
# 18   {'airplane': {'precision': 0.9393939393939394,...       0.894219
#
#      UAV recall    UAV f1  Total f1 Training Config  \
# 123    0.884511  0.821581  0.904213             NaN
# 47     0.896609  0.856723  0.922019             NaN
# 171    0.910479  0.883042  0.934616             NaN
# 234    0.921228  0.892244  0.931636             NaN
# 18     0.927373  0.909235  0.949868             NaN
#
#                                        test UAV report  test UAV precision  \
# 123  {'precision': 0.7534883720930232, 'recall': 0....            0.753488
# 47   {'precision': 0.8952380952380953, 'recall': 0....            0.895238
# 171  {'precision': 0.6271186440677966, 'recall': 0....            0.627119
# 234  {'precision': 0.7058823529411765, 'recall': 0....            0.705882
# 18   {'precision': 0.7741935483870968, 'recall': 0....            0.774194
#
#      test UAV recall  test UAV f1-score
# 123         0.964286           0.845953
# 47          0.878505           0.886792
# 171         0.925000           0.747475
# 234         0.923077           0.800000
# 18          0.941176           0.849558

# %%
unified_results = pd.DataFrame()
for file in glob.glob('./Features Extraction Results unified durations/features_extraction_results*'):
  print(file)
  with open(file, 'rb') as f:
    unified_results = unified_results.append(pickle.load(f))

unified_results.reset_index(drop=True, inplace=True)
# Out:
# ./Features Extraction Results unified durations/features_extraction_results_02_04_2024, 11:06:41
# ./Features Extraction Results unified durations/features_extraction_results_02_06_2024, 08:14:55

# %%
unified_results_RF = unified_results[unified_results['Model'] == 'RF']
unified_results_XGB = unified_results[unified_results['Model'] == 'XGB']

# %%
max_idx = unified_results_RF.groupby(['Sample Duration','Model'])['UAV f1'].idxmax()
u_df_max_RF = unified_results_RF.loc[max_idx.values]
u_df_max_RF['test UAV report'] = extract_from_column(u_df_max_RF, 'Evaluation Report', 'uav')
u_df_max_RF['test UAV precision'] = extract_from_column(u_df_max_RF, 'test UAV report', 'precision')
u_df_max_RF['test UAV recall'] = extract_from_column(u_df_max_RF, 'test UAV report', 'recall')
u_df_max_RF['test UAV f1-score'] = extract_from_column(u_df_max_RF, 'test UAV report', 'f1-score')

# %%
u_df_max_RF
# Out:
#                datetime  Sample Duration  \
# 5  02/04/2024, 11:06:41                5
# 6  02/04/2024, 11:06:41               10
# 7  02/04/2024, 11:06:41               15
# 8  02/04/2024, 11:06:41               20
# 9  02/04/2024, 11:06:41               25
#
#                                           Test Files  \
# 5  [NIR_airplane_20231023-13275_20231023-181630.j...
# 6  [NIR_airplane_20231023-13275_20231023-181630.j...
# 7  [NIR_airplane_20231023-13275_20231023-181630.j...
# 8  [NIR_airplane_20231023-13275_20231023-181630.j...
# 9  [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                         Split Config  \
# 5  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 6  {'sample_duration': 10, 'overlap_factor': 0.25...
# 7  {'sample_duration': 15, 'overlap_factor': 0.25...
# 8  {'sample_duration': 20, 'overlap_factor': 0.25...
# 9  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                      Features Config Model  \
# 5  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 6  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 7  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 8  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 9  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                  Model Config  \
# 5  {'max_depth': 7, 'model_random_state': 42}
# 6  {'max_depth': 7, 'model_random_state': 42}
# 7  {'max_depth': 7, 'model_random_state': 42}
# 8  {'max_depth': 7, 'model_random_state': 42}
# 9  {'max_depth': 7, 'model_random_state': 42}
#
#                                    Evaluation Report  UAV precision  \
# 5  {'airplane': {'precision': 0.8164251207729468,...       0.820987
# 6  {'airplane': {'precision': 0.8602150537634409,...       0.820987
# 7  {'airplane': {'precision': 0.8703703703703703,...       0.820987
# 8  {'airplane': {'precision': 0.875, 'recall': 1....       0.820987
# 9  {'airplane': {'precision': 0.9259259259259259,...       0.820987
#
#    UAV recall    UAV f1  Total f1  \
# 5    0.938095  0.870779  0.926327
# 6    0.938095  0.870779  0.926327
# 7    0.938095  0.870779  0.926327
# 8    0.938095  0.870779  0.926327
# 9    0.938095  0.870779  0.926327
#
#                                      test UAV report  test UAV precision  \
# 5  {'precision': 0.8577981651376146, 'recall': 0....            0.857798
# 6  {'precision': 0.8547008547008547, 'recall': 0....            0.854701
# 7  {'precision': 0.9285714285714286, 'recall': 0....            0.928571
# 8  {'precision': 0.9090909090909091, 'recall': 0....            0.909091
# 9  {'precision': 0.9090909090909091, 'recall': 0....            0.909091
#
#    test UAV recall  test UAV f1-score training type
# 5         0.809524           0.832962       unified
# 6         0.869565           0.862069       unified
# 7         0.866667           0.896552       unified
# 8         0.909091           0.909091       unified
# 9         0.952381           0.930233       unified

# %%
df_max_RF['training type'] = 'individual'
u_df_max_RF['training type'] = 'unified'

# %%
df_max_RF
# Out:
#                  datetime  Sample Duration  \
# 123  01/20/2024, 21:26:14                5
# 47   01/20/2024, 21:26:14               10
# 171  01/20/2024, 21:26:14               15
# 234  01/21/2024, 05:43:12               20
# 18   01/20/2024, 21:26:14               25
#
#                                             Test Files  \
# 123  [NIR_airplane_20230603-534_20230603-010658.jso...
# 47   [NIR_airplane_20231023-13275_20231023-181630.j...
# 171  [NIR_airplane_20231023-15264_20231023-183229.j...
# 234  [NIR_airplane_20231023-15264_20231023-183229.j...
# 18   [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                           Split Config  \
# 123  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 47   {'sample_duration': 10, 'overlap_factor': 0.25...
# 171  {'sample_duration': 15, 'overlap_factor': 0.25...
# 234  {'sample_duration': 20, 'overlap_factor': 0.25...
# 18   {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 123  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 47   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 171  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 234  {'date': 2012024, 'extremum': False, 'std': Fa...    RF
# 18   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                       Model Config  \
# 123  {'max_depth': None, 'model_random_state': 42}
# 47   {'max_depth': None, 'model_random_state': 24}
# 171  {'max_depth': None, 'model_random_state': 42}
# 234    {'max_depth': 10, 'model_random_state': 24}
# 18     {'max_depth': 10, 'model_random_state': 24}
#
#                                      Evaluation Report  UAV precision  \
# 123  {'airplane': {'precision': 0.9810126582278481,...       0.778403
# 47   {'airplane': {'precision': 0.9629629629629629,...       0.827140
# 171  {'airplane': {'precision': 0.8636363636363636,...       0.860131
# 234  {'airplane': {'precision': 0.9642857142857143,...       0.870085
# 18   {'airplane': {'precision': 0.9393939393939394,...       0.894219
#
#      UAV recall    UAV f1  Total f1 Training Config  \
# 123    0.884511  0.821581  0.904213             NaN
# 47     0.896609  0.856723  0.922019             NaN
# 171    0.910479  0.883042  0.934616             NaN
# 234    0.921228  0.892244  0.931636             NaN
# 18     0.927373  0.909235  0.949868             NaN
#
#                                        test UAV report  test UAV precision  \
# 123  {'precision': 0.7534883720930232, 'recall': 0....            0.753488
# 47   {'precision': 0.8952380952380953, 'recall': 0....            0.895238
# 171  {'precision': 0.6271186440677966, 'recall': 0....            0.627119
# 234  {'precision': 0.7058823529411765, 'recall': 0....            0.705882
# 18   {'precision': 0.7741935483870968, 'recall': 0....            0.774194
#
#      test UAV recall  test UAV f1-score training type
# 123         0.964286           0.845953    individual
# 47          0.878505           0.886792    individual
# 171         0.925000           0.747475    individual
# 234         0.923077           0.800000    individual
# 18          0.941176           0.849558    individual

# %%
df = df_max_RF.append(u_df_max_RF)

# %%
df
# Out:
#                  datetime  Sample Duration  \
# 123  01/20/2024, 21:26:14                5
# 47   01/20/2024, 21:26:14               10
# 171  01/20/2024, 21:26:14               15
# 234  01/21/2024, 05:43:12               20
# 18   01/20/2024, 21:26:14               25
# 5    02/04/2024, 11:06:41                5
# 6    02/04/2024, 11:06:41               10
# 7    02/04/2024, 11:06:41               15
# 8    02/04/2024, 11:06:41               20
# 9    02/04/2024, 11:06:41               25
#
#                                             Test Files  \
# 123  [NIR_airplane_20230603-534_20230603-010658.jso...
# 47   [NIR_airplane_20231023-13275_20231023-181630.j...
# 171  [NIR_airplane_20231023-15264_20231023-183229.j...
# 234  [NIR_airplane_20231023-15264_20231023-183229.j...
# 18   [NIR_airplane_20231023-13275_20231023-181630.j...
# 5    [NIR_airplane_20231023-13275_20231023-181630.j...
# 6    [NIR_airplane_20231023-13275_20231023-181630.j...
# 7    [NIR_airplane_20231023-13275_20231023-181630.j...
# 8    [NIR_airplane_20231023-13275_20231023-181630.j...
# 9    [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                           Split Config  \
# 123  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 47   {'sample_duration': 10, 'overlap_factor': 0.25...
# 171  {'sample_duration': 15, 'overlap_factor': 0.25...
# 234  {'sample_duration': 20, 'overlap_factor': 0.25...
# 18   {'sample_duration': 25, 'overlap_factor': 0.25...
# 5    {'sample_duration': 5, 'overlap_factor': 0.25,...
# 6    {'sample_duration': 10, 'overlap_factor': 0.25...
# 7    {'sample_duration': 15, 'overlap_factor': 0.25...
# 8    {'sample_duration': 20, 'overlap_factor': 0.25...
# 9    {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 123  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 47   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 171  {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 234  {'date': 2012024, 'extremum': False, 'std': Fa...    RF
# 18   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 5    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 6    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 7    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 8    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 9    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
#
#                                       Model Config  \
# 123  {'max_depth': None, 'model_random_state': 42}
# 47   {'max_depth': None, 'model_random_state': 24}
# 171  {'max_depth': None, 'model_random_state': 42}
# 234    {'max_depth': 10, 'model_random_state': 24}
# 18     {'max_depth': 10, 'model_random_state': 24}
# 5       {'max_depth': 7, 'model_random_state': 42}
# 6       {'max_depth': 7, 'model_random_state': 42}
# 7       {'max_depth': 7, 'model_random_state': 42}
# 8       {'max_depth': 7, 'model_random_state': 42}
# 9       {'max_depth': 7, 'model_random_state': 42}
#
#                                      Evaluation Report  UAV precision  \
# 123  {'airplane': {'precision': 0.9810126582278481,...       0.778403
# 47   {'airplane': {'precision': 0.9629629629629629,...       0.827140
# 171  {'airplane': {'precision': 0.8636363636363636,...       0.860131
# 234  {'airplane': {'precision': 0.9642857142857143,...       0.870085
# 18   {'airplane': {'precision': 0.9393939393939394,...       0.894219
# 5    {'airplane': {'precision': 0.8164251207729468,...       0.820987
# 6    {'airplane': {'precision': 0.8602150537634409,...       0.820987
# 7    {'airplane': {'precision': 0.8703703703703703,...       0.820987
# 8    {'airplane': {'precision': 0.875, 'recall': 1....       0.820987
# 9    {'airplane': {'precision': 0.9259259259259259,...       0.820987
#
#      UAV recall    UAV f1  Total f1 Training Config  \
# 123    0.884511  0.821581  0.904213             NaN
# 47     0.896609  0.856723  0.922019             NaN
# 171    0.910479  0.883042  0.934616             NaN
# 234    0.921228  0.892244  0.931636             NaN
# 18     0.927373  0.909235  0.949868             NaN
# 5      0.938095  0.870779  0.926327             NaN
# 6      0.938095  0.870779  0.926327             NaN
# 7      0.938095  0.870779  0.926327             NaN
# 8      0.938095  0.870779  0.926327             NaN
# 9      0.938095  0.870779  0.926327             NaN
#
#                                        test UAV report  test UAV precision  \
# 123  {'precision': 0.7534883720930232, 'recall': 0....            0.753488
# 47   {'precision': 0.8952380952380953, 'recall': 0....            0.895238
# 171  {'precision': 0.6271186440677966, 'recall': 0....            0.627119
# 234  {'precision': 0.7058823529411765, 'recall': 0....            0.705882
# 18   {'precision': 0.7741935483870968, 'recall': 0....            0.774194
# 5    {'precision': 0.8577981651376146, 'recall': 0....            0.857798
# 6    {'precision': 0.8547008547008547, 'recall': 0....            0.854701
# 7    {'precision': 0.9285714285714286, 'recall': 0....            0.928571
# 8    {'precision': 0.9090909090909091, 'recall': 0....            0.909091
# 9    {'precision': 0.9090909090909091, 'recall': 0....            0.909091
#
#      test UAV recall  test UAV f1-score training type
# 123         0.964286           0.845953    individual
# 47          0.878505           0.886792    individual
# 171         0.925000           0.747475    individual
# 234         0.923077           0.800000    individual
# 18          0.941176           0.849558    individual
# 5           0.809524           0.832962       unified
# 6           0.869565           0.862069       unified
# 7           0.866667           0.896552       unified
# 8           0.909091           0.909091       unified
# 9           0.952381           0.930233       unified

# %% [markdown]
# ####XGB

# %%
max_idx_XGB = results_XGB.groupby(['Sample Duration','Model'])['UAV f1'].idxmax()
df_max_XGB = results_XGB.loc[max_idx_XGB.values]

# %%
df_max_XGB['test UAV report'] = extract_from_column(df_max_XGB, 'Evaluation Report', 'uav')
df_max_XGB['test UAV precision'] = extract_from_column(df_max_XGB, 'test UAV report', 'precision')
df_max_XGB['test UAV recall'] = extract_from_column(df_max_XGB, 'test UAV report', 'recall')
df_max_XGB['test UAV f1-score'] = extract_from_column(df_max_XGB, 'test UAV report', 'f1-score')

# %%
max_idx = unified_results_XGB.groupby(['Sample Duration','Model'])['UAV f1'].idxmax()
u_df_max_XGB = unified_results_XGB.loc[max_idx.values]
u_df_max_XGB['test UAV report'] = extract_from_column(u_df_max_XGB, 'Evaluation Report', 'uav')
u_df_max_XGB['test UAV precision'] = extract_from_column(u_df_max_XGB, 'test UAV report', 'precision')
u_df_max_XGB['test UAV recall'] = extract_from_column(u_df_max_XGB, 'test UAV report', 'recall')
u_df_max_XGB['test UAV f1-score'] = extract_from_column(u_df_max_XGB, 'test UAV report', 'f1-score')

# %%
u_df_max_XGB
# Out:
#                 datetime  Sample Duration  \
# 30  02/06/2024, 08:14:55                5
# 31  02/06/2024, 08:14:55               10
# 32  02/06/2024, 08:14:55               15
# 33  02/06/2024, 08:14:55               20
# 34  02/06/2024, 08:14:55               25
#
#                                            Test Files  \
# 30  [NIR_airplane_20231023-13275_20231023-181630.j...
# 31  [NIR_airplane_20231023-13275_20231023-181630.j...
# 32  [NIR_airplane_20231023-13275_20231023-181630.j...
# 33  [NIR_airplane_20231023-13275_20231023-181630.j...
# 34  [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                          Split Config  \
# 30  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 31  {'sample_duration': 10, 'overlap_factor': 0.25...
# 32  {'sample_duration': 15, 'overlap_factor': 0.25...
# 33  {'sample_duration': 20, 'overlap_factor': 0.25...
# 34  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                       Features Config Model  \
# 30  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 31  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 32  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 33  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 34  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
#
#                                          Model Config  \
# 30  {'max_depth': 2, 'model_random_state': 42, 'et...
# 31  {'max_depth': 2, 'model_random_state': 42, 'et...
# 32  {'max_depth': 2, 'model_random_state': 42, 'et...
# 33  {'max_depth': 2, 'model_random_state': 42, 'et...
# 34  {'max_depth': 2, 'model_random_state': 42, 'et...
#
#                                     Evaluation Report  UAV precision  \
# 30  {'airplane': {'precision': 0.9162011173184358,...       0.898931
# 31  {'airplane': {'precision': 0.9195402298850575,...       0.898931
# 32  {'airplane': {'precision': 0.9038461538461539,...       0.898931
# 33  {'airplane': {'precision': 0.9459459459459459,...       0.898931
# 34  {'airplane': {'precision': 0.8928571428571429,...       0.898931
#
#     UAV recall    UAV f1  Total f1  \
# 30    0.943452  0.916146  0.952251
# 31    0.943452  0.916146  0.952251
# 32    0.943452  0.916146  0.952251
# 33    0.943452  0.916146  0.952251
# 34    0.943452  0.916146  0.952251
#
#                                       test UAV report  test UAV precision  \
# 30  {'precision': 0.9241706161137441, 'recall': 0....            0.924171
# 31  {'precision': 0.944954128440367, 'recall': 0.8...            0.944954
# 32  {'precision': 0.9710144927536232, 'recall': 0....            0.971014
# 33  {'precision': 0.9795918367346939, 'recall': 0....            0.979592
# 34  {'precision': 0.9459459459459459, 'recall': 0....            0.945946
#
#     test UAV recall  test UAV f1-score training type
# 30         0.844156           0.882353       unified
# 31         0.895652           0.919643       unified
# 32         0.893333           0.930556       unified
# 33         0.872727           0.923077       unified
# 34         0.833333           0.886076       unified

# %%
df_max_XGB['training type'] = 'individual'
u_df_max_XGB['training type'] = 'unified'

# %%
df = df.append(df_max_XGB)
df = df.append(u_df_max_XGB)

# %%
df
# Out:
#                   datetime  Sample Duration  \
# 123   01/20/2024, 21:26:14                5
# 47    01/20/2024, 21:26:14               10
# 171   01/20/2024, 21:26:14               15
# 234   01/21/2024, 05:43:12               20
# 18    01/20/2024, 21:26:14               25
# 5     02/04/2024, 11:06:41                5
# 6     02/04/2024, 11:06:41               10
# 7     02/04/2024, 11:06:41               15
# 8     02/04/2024, 11:06:41               20
# 9     02/04/2024, 11:06:41               25
# 1742  01/22/2024, 21:36:27                5
# 1766  01/22/2024, 21:36:27               10
# 1784  01/22/2024, 21:36:27               15
# 1722  01/22/2024, 21:19:19               20
# 1805  01/22/2024, 21:36:27               25
# 30    02/06/2024, 08:14:55                5
# 31    02/06/2024, 08:14:55               10
# 32    02/06/2024, 08:14:55               15
# 33    02/06/2024, 08:14:55               20
# 34    02/06/2024, 08:14:55               25
#
#                                              Test Files  \
# 123   [NIR_airplane_20230603-534_20230603-010658.jso...
# 47    [NIR_airplane_20231023-13275_20231023-181630.j...
# 171   [NIR_airplane_20231023-15264_20231023-183229.j...
# 234   [NIR_airplane_20231023-15264_20231023-183229.j...
# 18    [NIR_airplane_20231023-13275_20231023-181630.j...
# 5     [NIR_airplane_20231023-13275_20231023-181630.j...
# 6     [NIR_airplane_20231023-13275_20231023-181630.j...
# 7     [NIR_airplane_20231023-13275_20231023-181630.j...
# 8     [NIR_airplane_20231023-13275_20231023-181630.j...
# 9     [NIR_airplane_20231023-13275_20231023-181630.j...
# 1742  [NIR_airplane_20231023-13275_20231023-181630.j...
# 1766  [NIR_airplane_20231023-13275_20231023-181630.j...
# 1784  [NIR_airplane_20231023-15264_20231023-183229.j...
# 1722  [NIR_airplane_20231023-15264_20231023-183229.j...
# 1805  [NIR_airplane_20231024-7069_20231024-021810.js...
# 30    [NIR_airplane_20231023-13275_20231023-181630.j...
# 31    [NIR_airplane_20231023-13275_20231023-181630.j...
# 32    [NIR_airplane_20231023-13275_20231023-181630.j...
# 33    [NIR_airplane_20231023-13275_20231023-181630.j...
# 34    [NIR_airplane_20231023-13275_20231023-181630.j...
#
#                                            Split Config  \
# 123   {'sample_duration': 5, 'overlap_factor': 0.25,...
# 47    {'sample_duration': 10, 'overlap_factor': 0.25...
# 171   {'sample_duration': 15, 'overlap_factor': 0.25...
# 234   {'sample_duration': 20, 'overlap_factor': 0.25...
# 18    {'sample_duration': 25, 'overlap_factor': 0.25...
# 5     {'sample_duration': 5, 'overlap_factor': 0.25,...
# 6     {'sample_duration': 10, 'overlap_factor': 0.25...
# 7     {'sample_duration': 15, 'overlap_factor': 0.25...
# 8     {'sample_duration': 20, 'overlap_factor': 0.25...
# 9     {'sample_duration': 25, 'overlap_factor': 0.25...
# 1742  {'sample_duration': 5, 'overlap_factor': 0.25,...
# 1766  {'sample_duration': 10, 'overlap_factor': 0.25...
# 1784  {'sample_duration': 15, 'overlap_factor': 0.25...
# 1722  {'sample_duration': 20, 'overlap_factor': 0.25...
# 1805  {'sample_duration': 25, 'overlap_factor': 0.25...
# 30    {'sample_duration': 5, 'overlap_factor': 0.25,...
# 31    {'sample_duration': 10, 'overlap_factor': 0.25...
# 32    {'sample_duration': 15, 'overlap_factor': 0.25...
# 33    {'sample_duration': 20, 'overlap_factor': 0.25...
# 34    {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                         Features Config Model  \
# 123   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 47    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 171   {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 234   {'date': 2012024, 'extremum': False, 'std': Fa...    RF
# 18    {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 5     {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 6     {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 7     {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 8     {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 9     {'date': 2012024, 'extremum': True, 'std': Tru...    RF
# 1742  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 1766  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 1784  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 1722  {'date': 2012024, 'extremum': False, 'std': Fa...   XGB
# 1805  {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 30    {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 31    {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 32    {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 33    {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
# 34    {'date': 2012024, 'extremum': True, 'std': Tru...   XGB
#
#                                            Model Config  \
# 123       {'max_depth': None, 'model_random_state': 42}
# 47        {'max_depth': None, 'model_random_state': 24}
# 171       {'max_depth': None, 'model_random_state': 42}
# 234         {'max_depth': 10, 'model_random_state': 24}
# 18          {'max_depth': 10, 'model_random_state': 24}
# 5            {'max_depth': 7, 'model_random_state': 42}
# 6            {'max_depth': 7, 'model_random_state': 42}
# 7            {'max_depth': 7, 'model_random_state': 42}
# 8            {'max_depth': 7, 'model_random_state': 42}
# 9            {'max_depth': 7, 'model_random_state': 42}
# 1742  {'max_depth': 2, 'model_random_state': 42, 'et...
# 1766  {'max_depth': 7, 'model_random_state': 42, 'et...
# 1784  {'max_depth': 10, 'model_random_state': 42, 'e...
# 1722  {'max_depth': 10, 'model_random_state': 42, 'e...
# 1805  {'max_depth': 2, 'model_random_state': 42, 'et...
# 30    {'max_depth': 2, 'model_random_state': 42, 'et...
# 31    {'max_depth': 2, 'model_random_state': 42, 'et...
# 32    {'max_depth': 2, 'model_random_state': 42, 'et...
# 33    {'max_depth': 2, 'model_random_state': 42, 'et...
# 34    {'max_depth': 2, 'model_random_state': 42, 'et...
#
#                                       Evaluation Report  UAV precision  \
# 123   {'airplane': {'precision': 0.9810126582278481,...       0.778403
# 47    {'airplane': {'precision': 0.9629629629629629,...       0.827140
# 171   {'airplane': {'precision': 0.8636363636363636,...       0.860131
# 234   {'airplane': {'precision': 0.9642857142857143,...       0.870085
# 18    {'airplane': {'precision': 0.9393939393939394,...       0.894219
# 5     {'airplane': {'precision': 0.8164251207729468,...       0.820987
# 6     {'airplane': {'precision': 0.8602150537634409,...       0.820987
# 7     {'airplane': {'precision': 0.8703703703703703,...       0.820987
# 8     {'airplane': {'precision': 0.875, 'recall': 1....       0.820987
# 9     {'airplane': {'precision': 0.9259259259259259,...       0.820987
# 1742  {'airplane': {'precision': 0.9273743016759777,...       0.824759
# 1766  {'airplane': {'precision': 0.9506172839506173,...       0.842660
# 1784  {'airplane': {'precision': 0.8888888888888888,...       0.873916
# 1722  {'airplane': {'precision': 0.9333333333333333,...       0.903826
# 1805  {'airplane': {'precision': 0.9642857142857143,...       0.867682
# 30    {'airplane': {'precision': 0.9162011173184358,...       0.898931
# 31    {'airplane': {'precision': 0.9195402298850575,...       0.898931
# 32    {'airplane': {'precision': 0.9038461538461539,...       0.898931
# 33    {'airplane': {'precision': 0.9459459459459459,...       0.898931
# 34    {'airplane': {'precision': 0.8928571428571429,...       0.898931
#
#       UAV recall    UAV f1  Total f1 Training Config  \
# 123     0.884511  0.821581  0.904213             NaN
# 47      0.896609  0.856723  0.922019             NaN
# 171     0.910479  0.883042  0.934616             NaN
# 234     0.921228  0.892244  0.931636             NaN
# 18      0.927373  0.909235  0.949868             NaN
# 5       0.938095  0.870779  0.926327             NaN
# 6       0.938095  0.870779  0.926327             NaN
# 7       0.938095  0.870779  0.926327             NaN
# 8       0.938095  0.870779  0.926327             NaN
# 9       0.938095  0.870779  0.926327             NaN
# 1742    0.896938  0.853217  0.924634             NaN
# 1766    0.893618  0.864595  0.928945             NaN
# 1784    0.917556  0.892252  0.938274             NaN
# 1722    0.932493  0.917546  0.927369             NaN
# 1805    0.893108  0.873472  0.933542             NaN
# 30      0.943452  0.916146  0.952251             NaN
# 31      0.943452  0.916146  0.952251             NaN
# 32      0.943452  0.916146  0.952251             NaN
# 33      0.943452  0.916146  0.952251             NaN
# 34      0.943452  0.916146  0.952251             NaN
#
#                                         test UAV report  test UAV precision  \
# 123   {'precision': 0.7534883720930232, 'recall': 0....            0.753488
# 47    {'precision': 0.8952380952380953, 'recall': 0....            0.895238
# 171   {'precision': 0.6271186440677966, 'recall': 0....            0.627119
# 234   {'precision': 0.7058823529411765, 'recall': 0....            0.705882
# 18    {'precision': 0.7741935483870968, 'recall': 0....            0.774194
# 5     {'precision': 0.8577981651376146, 'recall': 0....            0.857798
# 6     {'precision': 0.8547008547008547, 'recall': 0....            0.854701
# 7     {'precision': 0.9285714285714286, 'recall': 0....            0.928571
# 8     {'precision': 0.9090909090909091, 'recall': 0....            0.909091
# 9     {'precision': 0.9090909090909091, 'recall': 0....            0.909091
# 1742  {'precision': 0.9414634146341463, 'recall': 0....            0.941463
# 1766  {'precision': 0.8807339449541285, 'recall': 0....            0.880734
# 1784  {'precision': 0.6842105263157895, 'recall': 0....            0.684211
# 1722  {'precision': 0.7058823529411765, 'recall': 0....            0.705882
# 1805  {'precision': 0.9230769230769231, 'recall': 0....            0.923077
# 30    {'precision': 0.9241706161137441, 'recall': 0....            0.924171
# 31    {'precision': 0.944954128440367, 'recall': 0.8...            0.944954
# 32    {'precision': 0.9710144927536232, 'recall': 0....            0.971014
# 33    {'precision': 0.9795918367346939, 'recall': 0....            0.979592
# 34    {'precision': 0.9459459459459459, 'recall': 0....            0.945946
#
#       test UAV recall  test UAV f1-score training type
# 123          0.964286           0.845953    individual
# 47           0.878505           0.886792    individual
# 171          0.925000           0.747475    individual
# 234          0.923077           0.800000    individual
# 18           0.941176           0.849558    individual
# 5            0.809524           0.832962       unified
# 6            0.869565           0.862069       unified
# 7            0.866667           0.896552       unified
# 8            0.909091           0.909091       unified
# 9            0.952381           0.930233       unified
# 1742         0.835498           0.885321    individual
# 1766         0.897196           0.888889    individual
# 1784         0.975000           0.804124    individual
# 1722         0.923077           0.800000    individual
# 1805         0.972973           0.947368    individual
# 30           0.844156           0.882353       unified
# 31           0.895652           0.919643       unified
# 32           0.893333           0.930556       unified
# 33           0.872727           0.923077       unified
# 34           0.833333           0.886076       unified

# %% [markdown]
# ####PLOTTING

# %%
g = sns.catplot(data=df, x = "Sample Duration", y = "test UAV f1-score", hue = "training type", col="Model", kind="bar", aspect=1.2, palette ="bright")

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
g = sns.catplot(data=df, x = "Sample Duration", y = "test UAV recall", hue = "training type", col="Model", kind="bar", aspect=1.2, palette ="bright")

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)
