# %% [markdown]
# ### imports

# %%
# imports

import io
import glob
import os
import sys
from datetime import datetime
import pickle
import warnings
warnings.filterwarnings('ignore')
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import fft
import pandas as pd
import seaborn as sns
from scipy import interpolate
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr

# Machine Learning
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report


# prompt: Access a folder on google drive and import the data locally
from google.colab import drive
drive.mount('/content/drive/')
# helper files
sys.path.append('/content/drive/MyDrive/Final Project UAV/')
from UAV_project_preprocessing_and_visualization_helper_functions import *
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Final Project UAV/
# Out:
# /content/drive/MyDrive/Final Project UAV

# %% [markdown]
# ### Loading results

# %%
all_results_df = pd.DataFrame()
for file in glob.glob('./Features Extraction Results/features_extraction_results*'):
  print(file)
  with open(file, 'rb') as f:
    all_results_df = all_results_df.append(pickle.load(f))
# Out:
# ./Features Extraction Results/features_extraction_results_01_20_2024, 21:26:14
# ./Features Extraction Results/features_extraction_results_01_21_2024, 05:43:12
# ./Features Extraction Results/features_extraction_results_01_21_2024, 06:18:31
# ./Features Extraction Results/features_extraction_results_01_22_2024, 06:47:07
# ./Features Extraction Results/features_extraction_results_01_22_2024, 07:28:08
# ./Features Extraction Results/features_extraction_results_01_22_2024, 07:41:17
# ./Features Extraction Results/features_extraction_results_01_22_2024, 09:20:06

# %%
all_results_df = all_results_df[all_results_df['Model'] == 'SVM']
all_results_df.reset_index(drop=True, inplace=True)

# %%
len(all_results_df)
# Out:
# 1000

# %%
all_results_df.sample(10)
# Out:
#                  datetime  Sample Duration  \
# 87   01/22/2024, 06:47:07               10
# 152  01/22/2024, 06:47:07               15
# 713  01/22/2024, 07:41:17               15
# 968  01/22/2024, 09:20:06               25
# 659  01/22/2024, 07:41:17               10
# 913  01/22/2024, 09:20:06               15
# 193  01/22/2024, 06:47:07               20
# 120  01/22/2024, 06:47:07               15
# 481  01/22/2024, 07:28:08               20
# 493  01/22/2024, 07:28:08               20
#
#                                             Test Files  \
# 87   [NIR_airplane_20231023-13275_20231023-181630.j...
# 152  [NIR_airplane_20231023-15264_20231023-183229.j...
# 713  [NIR_airplane_20231023-15264_20231023-183229.j...
# 968  [NIR_airplane_20231024-7069_20231024-021810.js...
# 659  [NIR_airplane_20231023-13275_20231023-181630.j...
# 913  [NIR_airplane_20231023-15264_20231023-183229.j...
# 193  [NIR_airplane_20231023-15264_20231023-183229.j...
# 120  [NIR_airplane_20231023-15264_20231023-183229.j...
# 481  [NIR_airplane_20231023-15264_20231023-183229.j...
# 493  [NIR_airplane_20231023-15264_20231023-183229.j...
#
#                                           Split Config  \
# 87   {'sample_duration': 10, 'overlap_factor': 0.25...
# 152  {'sample_duration': 15, 'overlap_factor': 0.25...
# 713  {'sample_duration': 15, 'overlap_factor': 0.25...
# 968  {'sample_duration': 25, 'overlap_factor': 0.25...
# 659  {'sample_duration': 10, 'overlap_factor': 0.25...
# 913  {'sample_duration': 15, 'overlap_factor': 0.25...
# 193  {'sample_duration': 20, 'overlap_factor': 0.25...
# 120  {'sample_duration': 15, 'overlap_factor': 0.25...
# 481  {'sample_duration': 20, 'overlap_factor': 0.25...
# 493  {'sample_duration': 20, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 87   {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 152  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 713  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 968  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 659  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 913  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 193  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 120  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 481  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 493  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
#
#                                           Model Config  \
# 87   {'kernel': 'poly', 'gamma': 1, 'degree': 2, 'C...
# 152  {'kernel': 'poly', 'gamma': 10, 'degree': 4, '...
# 713  {'kernel': 'rbf', 'gamma': 1, 'degree': 3, 'C'...
# 968  {'kernel': 'linear', 'gamma': 0.1, 'degree': 3...
# 659  {'kernel': 'linear', 'gamma': 100, 'degree': 3...
# 913  {'kernel': 'rbf', 'gamma': 1, 'degree': 3, 'C'...
# 193  {'kernel': 'poly', 'gamma': 0.1, 'degree': 3, ...
# 120  {'kernel': 'poly', 'gamma': 0.1, 'degree': 2, ...
# 481  {'kernel': 'poly', 'gamma': 0.1, 'degree': 3, ...
# 493  {'kernel': 'poly', 'gamma': 0.1, 'degree': 3, ...
#
#                                      Evaluation Report  UAV precision  \
# 87   {'airplane': {'precision': 0.9066666666666666,...       0.660353
# 152  {'airplane': {'precision': 0.7169811320754716,...       0.754227
# 713  {'airplane': {'precision': 1.0, 'recall': 0.14...       0.000000
# 968  {'airplane': {'precision': 0.7105263157894737,...       0.768833
# 659  {'airplane': {'precision': 0.7956989247311828,...       0.768076
# 913  {'airplane': {'precision': 0.9090909090909091,...       0.000000
# 193  {'airplane': {'precision': 0.9, 'recall': 0.96...       0.878040
# 120  {'airplane': {'precision': 0.7111111111111111,...       0.727180
# 481  {'airplane': {'precision': 0.875, 'recall': 1....       0.903228
# 493  {'airplane': {'precision': 0.8709677419354839,...       0.897356
#
#      UAV recall    UAV f1  Total f1
# 87     0.739075  0.689783  0.824567
# 152    0.758587  0.752348  0.842374
# 713    0.000000  0.000000  0.441811
# 968    0.838026  0.799321  0.879299
# 659    0.832176  0.784793  0.872408
# 913    0.000000  0.000000  0.460504
# 193    0.852321  0.861374  0.889033
# 120    0.693906  0.704743  0.833527
# 481    0.852595  0.870719  0.896391
# 493    0.831972  0.858872  0.886874

# %%
def extract_from_column(df, col, field):
  return df[col].apply(lambda x: x[field])

def features_type(df):
  # extremum = extract_from_column(df, 'Features Config', 'extremum')
  # curve = extract_from_column(df, 'Features Config', 'curve')
  # f = zip(extremum, curve)
  d_map = {
    (True, True): 'all',
    (True, False): 'range dependent',
    (False, True): 'range independent',
    (False, False): 'none'
  }
  return df['Features Config'].apply(lambda x: d_map[(x['extremum'], x['curve'])])

# %%
all_results_df['kernel'] = extract_from_column(all_results_df, 'Model Config', 'kernel')
all_results_df['C'] = extract_from_column(all_results_df, 'Model Config', 'C')
all_results_df['gamma'] = extract_from_column(all_results_df, 'Model Config', 'gamma')
all_results_df['degree'] = extract_from_column(all_results_df, 'Model Config', 'degree')

all_results_df['Model Random State'] = extract_from_column(all_results_df, 'Model Config', 'model_random_state')
all_results_df['Split Random State'] = extract_from_column(all_results_df, 'Split Config', 'random_state')
all_results_df['Features Type'] = features_type(all_results_df)

# %%
all_results_df.sample(10)
# Out:
#                  datetime  Sample Duration  \
# 535  01/22/2024, 07:28:08               20
# 878  01/22/2024, 09:20:06               10
# 903  01/22/2024, 09:20:06               15
# 284  01/22/2024, 06:47:07               25
# 646  01/22/2024, 07:41:17               10
# 668  01/22/2024, 07:41:17               10
# 915  01/22/2024, 09:20:06               15
# 517  01/22/2024, 07:28:08               20
# 891  01/22/2024, 09:20:06               15
# 738  01/22/2024, 07:41:17               20
#
#                                             Test Files  \
# 535  [NIR_airplane_20231023-15264_20231023-183229.j...
# 878  [NIR_airplane_20231023-13275_20231023-181630.j...
# 903  [NIR_airplane_20231023-15264_20231023-183229.j...
# 284  [NIR_airplane_20231024-7069_20231024-021810.js...
# 646  [NIR_airplane_20231023-13275_20231023-181630.j...
# 668  [NIR_airplane_20231023-13275_20231023-181630.j...
# 915  [NIR_airplane_20231023-15264_20231023-183229.j...
# 517  [NIR_airplane_20231023-15264_20231023-183229.j...
# 891  [NIR_airplane_20231023-15264_20231023-183229.j...
# 738  [NIR_airplane_20231023-15264_20231023-183229.j...
#
#                                           Split Config  \
# 535  {'sample_duration': 20, 'overlap_factor': 0.25...
# 878  {'sample_duration': 10, 'overlap_factor': 0.25...
# 903  {'sample_duration': 15, 'overlap_factor': 0.25...
# 284  {'sample_duration': 25, 'overlap_factor': 0.25...
# 646  {'sample_duration': 10, 'overlap_factor': 0.25...
# 668  {'sample_duration': 10, 'overlap_factor': 0.25...
# 915  {'sample_duration': 15, 'overlap_factor': 0.25...
# 517  {'sample_duration': 20, 'overlap_factor': 0.25...
# 891  {'sample_duration': 15, 'overlap_factor': 0.25...
# 738  {'sample_duration': 20, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 535  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 878  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 903  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 284  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 646  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 668  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 915  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 517  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 891  {'date': 2012024, 'extremum': False, 'std': Fa...   SVM
# 738  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
#
#                                           Model Config  \
# 535  {'kernel': 'poly', 'gamma': 10, 'degree': 3, '...
# 878  {'kernel': 'rbf', 'gamma': 10, 'degree': 3, 'C...
# 903  {'kernel': 'rbf', 'gamma': 100, 'degree': 3, '...
# 284  {'kernel': 'poly', 'gamma': 10, 'degree': 4, '...
# 646  {'kernel': 'linear', 'gamma': 10, 'degree': 3,...
# 668  {'kernel': 'rbf', 'gamma': 0.1, 'degree': 3, '...
# 915  {'kernel': 'rbf', 'gamma': 100, 'degree': 3, '...
# 517  {'kernel': 'poly', 'gamma': 0.1, 'degree': 3, ...
# 891  {'kernel': 'linear', 'gamma': 100, 'degree': 3...
# 738  {'kernel': 'linear', 'gamma': 10, 'degree': 3,...
#
#                                      Evaluation Report  UAV precision  \
# 535  {'airplane': {'precision': 0.8709677419354839,...       0.897716
# 878  {'airplane': {'precision': 0.0, 'recall': 0.0,...       0.000000
# 903  {'airplane': {'precision': 0.11382113821138211...       0.046440
# 284  {'airplane': {'precision': 0.84375, 'recall': ...       0.732768
# 646  {'airplane': {'precision': 0.8085106382978723,...       0.799072
# 668  {'airplane': {'precision': 0.9384615384615385,...       0.604802
# 915  {'airplane': {'precision': 0.0, 'recall': 0.0,...       0.000000
# 517  {'airplane': {'precision': 0.8709677419354839,...       0.897716
# 891  {'airplane': {'precision': 0.7708333333333334,...       0.795819
# 738  {'airplane': {'precision': 0.8709677419354839,...       0.877117
#
#      UAV recall    UAV f1  Total f1  kernel       C  gamma  degree  \
# 535    0.841239  0.864305  0.886909    poly  1000.0   10.0       3
# 878    0.000000  0.000000  0.461724     rbf  1000.0   10.0       3
# 903    0.200000  0.075377  0.024987     rbf     0.1  100.0       3
# 284    0.780271  0.737206  0.826649    poly   100.0   10.0       4
# 646    0.793955  0.783698  0.877480  linear     1.0   10.0       3
# 668    0.900461  0.721323  0.839323     rbf    10.0    0.1       3
# 915    0.000000  0.000000  0.433019     rbf   100.0  100.0       3
# 517    0.841239  0.864305  0.886909    poly   100.0    0.1       3
# 891    0.784594  0.787082  0.881356  linear    10.0  100.0       3
# 738    0.857793  0.864862  0.884883  linear  1000.0   10.0       3
#
#      Model Random State  Split Random State      Features Type
# 535                  42                  42                all
# 878                  42                  42  range independent
# 903                  42                  42  range independent
# 284                  42                  42  range independent
# 646                  42                  42                all
# 668                  42                  42                all
# 915                  42                  42  range independent
# 517                  42                  42                all
# 891                  42                  42  range independent
# 738                  42                  42                all

# %%
all_results_df[all_results_df['UAV f1'] == all_results_df['UAV f1'].max()]
# Out:
#                  datetime  Sample Duration  \
# 720  01/22/2024, 07:41:17               20
# 721  01/22/2024, 07:41:17               20
# 722  01/22/2024, 07:41:17               20
# 723  01/22/2024, 07:41:17               20
#
#                                             Test Files  \
# 720  [NIR_airplane_20231023-15264_20231023-183229.j...
# 721  [NIR_airplane_20231023-15264_20231023-183229.j...
# 722  [NIR_airplane_20231023-15264_20231023-183229.j...
# 723  [NIR_airplane_20231023-15264_20231023-183229.j...
#
#                                           Split Config  \
# 720  {'sample_duration': 20, 'overlap_factor': 0.25...
# 721  {'sample_duration': 20, 'overlap_factor': 0.25...
# 722  {'sample_duration': 20, 'overlap_factor': 0.25...
# 723  {'sample_duration': 20, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 720  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 721  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 722  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
# 723  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
#
#                                           Model Config  \
# 720  {'kernel': 'linear', 'gamma': 0.1, 'degree': 3...
# 721  {'kernel': 'linear', 'gamma': 1, 'degree': 3, ...
# 722  {'kernel': 'linear', 'gamma': 10, 'degree': 3,...
# 723  {'kernel': 'linear', 'gamma': 100, 'degree': 3...
#
#                                      Evaluation Report  UAV precision  \
# 720  {'airplane': {'precision': 0.8387096774193549,...       0.921514
# 721  {'airplane': {'precision': 0.8387096774193549,...       0.921514
# 722  {'airplane': {'precision': 0.8387096774193549,...       0.921514
# 723  {'airplane': {'precision': 0.8387096774193549,...       0.921514
#
#      UAV recall    UAV f1  Total f1  kernel    C  gamma  degree  \
# 720    0.857519  0.885167  0.904587  linear  0.1    0.1       3
# 721    0.857519  0.885167  0.904587  linear  0.1    1.0       3
# 722    0.857519  0.885167  0.904587  linear  0.1   10.0       3
# 723    0.857519  0.885167  0.904587  linear  0.1  100.0       3
#
#      Model Random State  Split Random State Features Type
# 720                  42                  42           all
# 721                  42                  42           all
# 722                  42                  42           all
# 723                  42                  42           all

# %%
all_results_df[all_results_df['UAV recall'] == all_results_df['UAV recall'].max()]
# Out:
#                  datetime  Sample Duration  \
# 780  01/22/2024, 07:41:17               25
#
#                                             Test Files  \
# 780  [NIR_airplane_20231024-7069_20231024-021810.js...
#
#                                           Split Config  \
# 780  {'sample_duration': 25, 'overlap_factor': 0.25...
#
#                                        Features Config Model  \
# 780  {'date': 2012024, 'extremum': True, 'std': Tru...   SVM
#
#                                           Model Config  \
# 780  {'kernel': 'rbf', 'gamma': 0.1, 'degree': 3, '...
#
#                                      Evaluation Report  UAV precision  \
# 780  {'airplane': {'precision': 0.8421052631578947,...        0.33976
#
#      UAV recall   UAV f1  Total f1 kernel    C  gamma  degree  \
# 780    0.973227  0.49804  0.480707    rbf  0.1    0.1       3
#
#      Model Random State  Split Random State Features Type
# 780                  42                  42           all

# %%
all_results_df['Evaluation Report'].iloc[720]
# Out:
# {'airplane': {'precision': 0.8387096774193549,
#   'recall': 0.9285714285714286,
#   'f1-score': 0.8813559322033899,
#   'support': 28},
#  'uav': {'precision': 0.7111111111111111,
#   'recall': 0.8205128205128205,
#   'f1-score': 0.7619047619047619,
#   'support': 39},
#  'bird': {'precision': 0.5,
#   'recall': 0.2857142857142857,
#   'f1-score': 0.36363636363636365,
#   'support': 7},
#  'static-object': {'precision': 0.9852941176470589,
#   'recall': 0.9436619718309859,
#   'f1-score': 0.9640287769784172,
#   'support': 142},
#  'accuracy': 0.8981481481481481,
#  'macro avg': {'precision': 0.7587787265443813,
#   'recall': 0.7446151266573802,
#   'f1-score': 0.7427314586807331,
#   'support': 216},
#  'weighted avg': {'precision': 0.9010600416988779,
#   'recall': 0.8981481481481481,
#   'f1-score': 0.8973601513535667,
#   'support': 216}}

# %% [markdown]
# ### Slicing

# %%
slice1_config = {
    'Model' : 'SVM',
    'Split Random State' : 42,
    'Features Type' : 'range independent',
    'kernel' : 'poly',
    'gamma' : 0.1,
    'C' : 1,
}

# %%
# prompt: slice a dataframe according to a given column value dictionary

# slice_df = all_results_df[all_results_df['Model'] == slice_config['Model']]
slice1_df = all_results_df[all_results_df['Features Type'] == slice1_config['Features Type']]
slice1_df = slice1_df[slice1_df['kernel'] == slice1_config['kernel']]
slice1_df = slice1_df[slice1_df['gamma'] == slice1_config['gamma']]
slice1_df = slice1_df[slice1_df['C'] == slice1_config['C']]

# %%
# slice_df['UAV recall'].max()

# %%
# slice_df[slice_df['UAV recall'] == slice_df['UAV recall'].max()]

# %%
# slice_df[slice_df['UAV precision'] == slice_df['UAV precision'].max()]

# %%
# slice_df[slice_df['UAV f1'] == slice_df['UAV f1'].max()]

# %%
g = sns.catplot(data=slice1_df, x = "Sample Duration", y = "UAV f1", hue = "degree", col="Split Random State", kind="bar", aspect = 2, palette ="bright")

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %% [markdown]
# ### Compare features

# %%
slice2_config = {
    'Model' : 'SVM',
    'Split Random State' : 42,
    'Features Type' : 'range independent',
    'kernel' : 'poly',
    'gamma' : 0.1,
    'C' : 1,
    'degree' : 3
}

# %%
slice2_df = all_results_df[all_results_df['kernel'] == slice2_config['kernel']]
slice2_df = slice2_df[slice2_df['gamma'] == slice2_config['gamma']]
slice2_df = slice2_df[slice2_df['C'] == slice2_config['C']]
slice2_df = slice2_df[slice2_df['degree'] == slice2_config['degree']]

# %%
hue_order = ['range independent', 'all']

g = sns.catplot(data=slice2_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="bar",hue_order=hue_order, aspect = 2)

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)

# %%
slice3_config = {
    'Model' : 'SVM',
    'Split Random State' : 42,
    'Features Type' : 'range independent',
    'gamma' : 0.1,
    'C' : 1,
    'degree' : 3
}

# %%
slice3_df = all_results_df[all_results_df['Features Type'] == slice3_config['Features Type']]
slice3_df = slice3_df[slice3_df['gamma'] == slice3_config['gamma']]
slice3_df = slice3_df[slice3_df['C'] == slice3_config['C']]
slice3_df = slice3_df[slice3_df['degree'] == slice3_config['degree']]

# %%
# hue_order = ['range dependent','range independent', 'all']

# g = sns.catplot(data=feat_slice_df, x = "Sample Duration", y = "UAV f1", hue = "Features Type", col="Split Random State", kind="bar",hue_order=hue_order, aspect = 2)
g = sns.catplot(data=slice3_df, x = "Sample Duration", y = "UAV f1", hue = "kernel", col="Split Random State", kind="point", aspect = 2)

for ax in g.axes.ravel():
    for c in ax.containers:
        labels = ['%0.2f' % v for v in c.datavalues]
        ax.bar_label(c, labels=labels, label_type='edge')
    # plt.xticks(rotation=45)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    ax.margins(y=0.2)
